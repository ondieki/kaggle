# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split

# %%
df = pd.read_csv('data/train.csv')
df = df.fillna(0)
testdf = pd.read_csv('data/test_v2.csv')

# %%
testdf.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000001            1            0    1  12:35    OK     10002
# 1     10000001            2            0    1  12:36    OK     10002
# 2     10000002            1            0    4  12:19    PA     10003
# 3     10000002            2            0    4  12:21    PA     10003
# 4     10000003            1            0    3  17:12    AR     10004
#
#    group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 0           1          0        9   ...             3                  9  0
# 1           1          0        9   ...             3                  9  2
# 2           1          1        7   ...             2                 15  2
# 3           1          1        7   ...             2                 15  2
# 4           1          0        4   ...             3                  1  1
#
#    B  C  D  E  F  G  cost
# 0  0  1  1  0  0  4   543
# 1  1  1  3  1  3  2   611
# 2  0  2  3  1  2  2   691
# 3  0  2  3  1  2  2   695
# 4  0  1  1  0  2  2   628
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time', u'state', u'location', u'group_size', u'homeowner', u'car_age', u'car_value', u'risk_factor', u'age_oldest', u'age_youngest', u'married_couple', u'C_previous', u'duration_previous', u'A', u'B', u'C', u'D', u'E', u'F', u'G', u'cost'], dtype='object')

# %%
df.record_type.value_counts()
# Out:
# 0    568240
# 1     97009
# dtype: int64

# %%
df.A.value_counts()
# Out:
# 1    426067
# 0    143691
# 2     95491
# dtype: int64

# %%
col_select = ["group_size", "homeowner", "car_age",
              "risk_factor", "age_oldest", "age_youngest", 
              "married_couple", "C_previous", "duration_previous",
              "A", "B", "C", "D", "E", "F", "G", "cost"]
X = df[col_select]
y = df.record_type

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y)

# %%
lm = LogisticRegression()
lm.fit(Xtrain, ytrain)
lm.score(Xtest, ytest)
# Out:
# 0.85415451588270308

# %%
rf = RandomForestClassifier()
rf.fit(Xtrain, ytrain)
rf.score(Xtest, ytest)
# Out:
# 0.8128889503526483

# %%
nb = MultinomialNB()
nb.fit(Xtrain, ytrain)
nb.score(Xtest,ytest)
# Out:
# 0.85428679658234774

# %%
for i in X.columns:
    print i
    print X.ix[:,i].value_counts()
# Out:
# 1    519305
# 2    136393
# 3      8856
# 4       695
# dtype: int64
# 1    356726
# 0    308523
# dtype: int64
# 1     71650
# 2     50389
# 7     46752
# 8     44453
# 6     44363
# 9     44218
# 4     40991
# 3     40391
# 10    39301
# 11    36173
# 5     32806
# 12    32113
# 13    26628
# 14    25026
# 15    19041
# ...
# 62    15
# 61    14
# 51    14
# 53    13
# 52    11
# 59    10
# 58     8
# 57     7
# 64     6
# 75     6
# 55     6
# 65     5
# 60     4
# 85     4
# 54     1
# Length: 67, dtype: int64
# 3    117571
# 4    110754
# 1     99476
# 2     97030
# dtype: int64
# 75    45211
# 24    21627
# 23    21489
# 25    21278
# 22    19692
# 26    18679
# 27    16046
# 28    15180
# 21    14255
# 29    13179
# 30    12874
# 31    11982
# 32    11658
# 33    11461
# 43    11321
# 55    11206
# 42    11129
# 52    11029
# 34    10980
# 53    10839
# 46    10748
# 56    10680
# 35    10665
# 48    10632
# 49    10595
# 54    10558
# 58    10462
# 51    10447
# 50    10250
# 44    10205
# 45    10190
# 20    10180
# 59    10169
# 41    10135
# 36     9948
# 57     9873
# 47     9860
# 37     9831
# 66     9707
# 38     9700
# 63     9663
# 65     9651
# 60     9617
# 40     9573
# 61     9491
# 39     9480
# 62     9348
# 64     9315
# 70     8278
# 69     7604
# 67     7538
# 68     6957
# 71     6825
# 19     6592
# 72     6194
# 73     5861
# 74     5646
# 18     1666
# Length: 58, dtype: int64
# 75    34262
# 23    24208
# 24    23635
# 25    23509
# 22    22290
# 26    20510
# 27    17718
# 21    17311
# 28    16832
# 29    14437
# 30    13807
# 20    13480
# 31    12961
# 32    12520
# 33    12118
# 34    11466
# 35    11080
# 55    10298
# 42    10200
# 19    10182
# 43    10117
# 52    10026
# 36     9904
# 48     9829
# 37     9825
# 53     9803
# 46     9743
# 51     9713
# 49     9674
# 58     9673
# 56     9581
# 38     9568
# 41     9533
# 54     9511
# 50     9510
# 45     9380
# 40     9365
# 44     9291
# 65     9142
# 57     9120
# 39     9085
# 47     8931
# 59     8901
# 60     8859
# 66     8800
# 62     8707
# 61     8697
# 63     8606
# 64     8591
# 70     7295
# 69     6987
# 68     6397
# 67     6187
# 71     6102
# 72     5234
# 73     5152
# 18     5093
# 74     5048
# 16     4478
# 17     2967
# Length: 60, dtype: int64
# 0    525692
# 1    139557
# dtype: int64
# 3    271160
# 1    172007
# 2    109184
# 4     94187
# dtype: int64
# 1     81570
# 15    79849
# 2     79595
# 3     70800
# 4     57485
# 5     49372
# 6     45379
# 7     37768
# 8     30752
# 9     26244
# 0     24926
# 10    18094
# 11    12718
# 12    11284
# 13    10963
# 14     9739
# dtype: int64
# 1    426067
# 0    143691
# 2     95491
# dtype: int64
# 0    363069
# 1    302180
# dtype: int64
# 3    271607
# 1    202945
# 2    133468
# 4     57229
# dtype: int64
# 3    408839
# 2    149793
# 1    106617
# dtype: int64
# 0    369085
# 1    296164
# dtype: int64
# 2    255806
# 0    216395
# 1    158613
# 3     34435
# dtype: int64
# 2    265237
# 3    191163
# 1    141946
# 4     66903
# dtype: int64
# 633    6024
# 637    5985
# 640    5935
# 626    5934
# 638    5916
# 639    5912
# 629    5896
# 642    5894
# 635    5875
# 623    5854
# 628    5823
# 621    5780
# 631    5777
# 624    5766
# 632    5766
# ...
# 418    1
# 416    1
# 922    1
# 408    1
# 917    1
# 400    1
# 911    1
# 385    1
# 888    1
# 376    1
# 375    1
# 881    1
# 362    1
# 873    1
# 863    1
# Length: 531, dtype: int64
